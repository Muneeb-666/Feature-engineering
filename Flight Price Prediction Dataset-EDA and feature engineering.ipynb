# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
train_set=pd.read_excel('Data_Train.xlsx')
test_set=pd.read_excel('Test_set.xlsx')

# %%
train_set.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
test_set.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
final_df=train_set.append(test_set)
# Out:
# C:\Users\NAJEEB\AppData\Local\Temp\ipykernel_6788\3110252030.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=train_set.append(test_set)

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
final_df.tail()
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2666          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2667             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2668        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2669          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 2666    20:30  20:25 07 Jun  23h 55m      1 stop         No info    NaN
# 2667    14:20         16:55   2h 35m    non-stop         No info    NaN
# 2668    21:50  04:25 07 Mar   6h 35m      1 stop         No info    NaN
# 2669    04:00         19:15  15h 15m      1 stop         No info    NaN
# 2670    04:55         19:15  14h 20m      1 stop         No info    NaN

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# # Feature engineering

# %%
final_df['Date_of_Journey'].str.split('/').str[2]
# Out:
# 0       2019
# 1       2019
# 2       2019
# 3       2019
# 4       2019
#         ...
# 2666    2019
# 2667    2019
# 2668    2019
# 2669    2019
# 2670    2019
# Name: Date_of_Journey, Length: 13354, dtype: object

# %%
final_df['Date']= final_df['Date_of_Journey'].str.split('/').str[0]
final_df['Month']=final_df['Date_of_Journey'].str.split('/').str[1]
final_df['Year']=final_df['Date_of_Journey'].str.split('/').str[2]

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0   01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  object
#  12  Month            13354 non-null  object
#  13  Year             13354 non-null  object
# dtypes: float64(1), object(13)
# memory usage: 1.5+ MB

# %%
final_df['Date']=final_df['Date'].astype(int)
final_df['Month']=final_df['Month'].astype(int)
final_df['Year']=final_df['Year'].astype(int)

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price  Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0    24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0     1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0     9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0    12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0     1
#
#    Month  Year
# 0      3  2019
# ...

# %%
final_df['Arrival_Time'].str.split(' ').str[0]
# Out:
# 0       01:10
# 1       13:15
# 2       04:25
# 3       23:30
# 4       21:35
#         ...
# 2666    20:25
# 2667    16:55
# 2668    04:25
# 2669    19:15
# 2670    19:15
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
final_df['Arrival_Time']=final_df['Arrival_Time'].str.split(' ').str[0]

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info    Price  Date  \
# 0    22:20        01:10   2h 50m    non-stop         No info   3897.0    24
# 1    05:50        13:15   7h 25m     2 stops         No info   7662.0     1
# 2    09:25        04:25      19h     2 stops         No info  13882.0     9
# 3    18:05        23:30   5h 25m      1 stop         No info   6218.0    12
# 4    16:50        21:35   4h 45m      1 stop         No info  13302.0     1
#
#    Month  Year
# 0      3  2019
# 1      5  2019
# ...

# %%
final_df['Arrival_Time'].str.split(':').str[0]
# Out:
# 0       01
# 1       13
# 2       04
# 3       23
# 4       21
#         ..
# 2666    20
# 2667    16
# 2668    04
# 2669    19
# 2670    19
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
final_df['Arrival_Minutes']=final_df['Arrival_Time'].str.split(':').str[0]
final_df['Arrival_Hours']=final_df['Arrival_Time'].str.split(':').str[1]

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info    Price  Date  \
# 0    22:20        01:10   2h 50m    non-stop         No info   3897.0    24
# 1    05:50        13:15   7h 25m     2 stops         No info   7662.0     1
# 2    09:25        04:25      19h     2 stops         No info  13882.0     9
# 3    18:05        23:30   5h 25m      1 stop         No info   6218.0    12
# 4    16:50        21:35   4h 45m      1 stop         No info  13302.0     1
#
#    Month  Year Arrival_Minutes Arrival_Hours
# ...

# %%
final_df['Arrival_Minutes']=final_df['Arrival_Minutes'].astype(int)
final_df['Arrival_Hours']=final_df['Arrival_Hours'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  int32
#  12  Month            13354 non-null  int32
#  13  Year             13354 non-null  int32
#  14  Arrival_Minutes  13354 non-null  int32
#  15  Arrival_Hours    13354 non-null  int32
# dtypes: float64(1), int32(5), object(10)
# ...

# %%
final_df.drop('Arrival_Time',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Duration Total_Stops Additional_Info    Price  Date  Month  Year  \
# 0    22:20   2h 50m    non-stop         No info   3897.0    24      3  2019
# 1    05:50   7h 25m     2 stops         No info   7662.0     1      5  2019
# 2    09:25      19h     2 stops         No info  13882.0     9      6  2019
# 3    18:05   5h 25m      1 stop         No info   6218.0    12      5  2019
# 4    16:50   4h 45m      1 stop         No info  13302.0     1      3  2019
#
#    Arrival_Minutes  Arrival_Hours
# ...

# %%
final_df['Dept_Minutes']=final_df['Dep_Time'].str.split(':').str[0]
final_df['Dept_Hours']=final_df['Dep_Time'].str.split(':').str[1]

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Duration Total_Stops Additional_Info    Price  Date  Month  Year  \
# 0    22:20   2h 50m    non-stop         No info   3897.0    24      3  2019
# 1    05:50   7h 25m     2 stops         No info   7662.0     1      5  2019
# 2    09:25      19h     2 stops         No info  13882.0     9      6  2019
# 3    18:05   5h 25m      1 stop         No info   6218.0    12      5  2019
# 4    16:50   4h 45m      1 stop         No info  13302.0     1      3  2019
#
# ...

# %%
final_df['Dept_Hours']=final_df['Dept_Hours'].astype(int)
final_df['Dept_Minutes']=final_df['Dept_Minutes'].astype(int)

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Duration Total_Stops Additional_Info    Price  Date  Month  Year  \
# 0    22:20   2h 50m    non-stop         No info   3897.0    24      3  2019
# 1    05:50   7h 25m     2 stops         No info   7662.0     1      5  2019
# 2    09:25      19h     2 stops         No info  13882.0     9      6  2019
# 3    18:05   5h 25m      1 stop         No info   6218.0    12      5  2019
# 4    16:50   4h 45m      1 stop         No info  13302.0     1      3  2019
#
# ...

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Duration Total_Stops Additional_Info    Price  Date  Month  Year  \
# 0    22:20   2h 50m    non-stop         No info   3897.0    24      3  2019
# 1    05:50   7h 25m     2 stops         No info   7662.0     1      5  2019
# 2    09:25      19h     2 stops         No info  13882.0     9      6  2019
# 3    18:05   5h 25m      1 stop         No info   6218.0    12      5  2019
# 4    16:50   4h 45m      1 stop         No info  13302.0     1      3  2019
#
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  Date             13354 non-null  int32
#  11  Month            13354 non-null  int32
#  12  Year             13354 non-null  int32
#  13  Arrival_Minutes  13354 non-null  int32
#  14  Arrival_Hours    13354 non-null  int32
#  15  Dept_Minutes     13354 non-null  int32
#  16  Dept_Hours       13354 non-null  int32
# ...

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Duration Total_Stops Additional_Info    Price  Date  Month  Year  \
# 0    22:20   2h 50m    non-stop         No info   3897.0    24      3  2019
# 1    05:50   7h 25m     2 stops         No info   7662.0     1      5  2019
# 2    09:25      19h     2 stops         No info  13882.0     9      6  2019
# 3    18:05   5h 25m      1 stop         No info   6218.0    12      5  2019
# 4    16:50   4h 45m      1 stop         No info  13302.0     1      3  2019
#
# ...

# %%
final_df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
final_df['Total_Stops']=final_df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'nan':1})

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Duration  Total_Stops Additional_Info    Price  Date  Month  Year  \
# 0    22:20   2h 50m          0.0         No info   3897.0    24      3  2019
# 1    05:50   7h 25m          2.0         No info   7662.0     1      5  2019
# 2    09:25      19h          2.0         No info  13882.0     9      6  2019
# 3    18:05   5h 25m          1.0         No info   6218.0    12      5  2019
# 4    16:50   4h 45m          1.0         No info  13302.0     1      3  2019
#
# ...

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Duration  Total_Stops Additional_Info    Price  Date  Month  Year  \
# 0    22:20   2h 50m          0.0         No info   3897.0    24      3  2019
# 1    05:50   7h 25m          2.0         No info   7662.0     1      5  2019
# 2    09:25      19h          2.0         No info  13882.0     9      6  2019
# 3    18:05   5h 25m          1.0         No info   6218.0    12      5  2019
# 4    16:50   4h 45m          1.0         No info  13302.0     1      3  2019
#
# ...

# %%
final_df['duration_hours']=final_df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Duration  Total_Stops Additional_Info    Price  Date  Month  Year  \
# 0    22:20   2h 50m          0.0         No info   3897.0    24      3  2019
# 1    05:50   7h 25m          2.0         No info   7662.0     1      5  2019
# 2    09:25      19h          2.0         No info  13882.0     9      6  2019
# 3    18:05   5h 25m          1.0         No info   6218.0    12      5  2019
# 4    16:50   4h 45m          1.0         No info  13302.0     1      3  2019
#
# ...

# %%
final_df['duration_hours']=final_df['duration_hours'].astype(int)
#We have to look for this error somewhere 5m is present
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [154], in <cell line: 1>()
# ----> 1 final_df['duration_hours']=final_df['duration_hours'].astype(int)
#
# File I:\New folder (2)\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File I:\New folder (2)\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
final_df[final_df['duration_hours']=='5m']
# Out:
#         Airline Date_of_Journey  Source Destination                  Route  \
# 6474  Air India       6/03/2019  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD
# 2660  Air India      12/03/2019  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD
#
#      Dep_Time Duration  Total_Stops Additional_Info    Price  Date  Month  \
# 6474    16:50       5m          2.0         No info  17327.0     6      3
# 2660    16:50       5m          2.0         No info      NaN    12      3
#
#       Year  Arrival_Minutes  Arrival_Hours  Dept_Minutes  Dept_Hours  \
# 6474  2019               16             55            16          50
# 2660  2019               16             55            16          50
#
#      duration_hours
# 6474             5m
# 2660             5m

# %%
final_df.drop(6474.,axis=0,inplace=True)
final_df.drop(2660,axis=0,inplace=True)

# %%
final_df[final_df['duration_hours']=='5m']
#solved
# Out:
# Empty DataFrame
# Columns: [Airline, Date_of_Journey, Source, Destination, Route, Dep_Time, Duration, Total_Stops, Additional_Info, Price, Date, Month, Year, Arrival_Minutes, Arrival_Hours, Dept_Minutes, Dept_Hours, duration_hours]
# Index: []

# %%
final_df['duration_hours'].head()
# Out:
# 0     2
# 1     7
# 2    19
# 3     5
# 4     4
# Name: duration_hours, dtype: object

# %%
final_df['duration_hours']=final_df['duration_hours'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13351 entries, 0 to 2670
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13351 non-null  object
#  1   Date_of_Journey  13351 non-null  object
#  2   Source           13351 non-null  object
#  3   Destination      13351 non-null  object
#  4   Route            13350 non-null  object
#  5   Dep_Time         13351 non-null  object
#  6   Duration         13351 non-null  object
#  7   Total_Stops      13350 non-null  float64
#  8   Additional_Info  13351 non-null  object
#  9   Price            10681 non-null  float64
#  10  Date             13351 non-null  int32
#  11  Month            13351 non-null  int32
#  12  Year             13351 non-null  int32
#  13  Arrival_Minutes  13351 non-null  int32
#  14  Arrival_Hours    13351 non-null  int32
#  15  Dept_Minutes     13351 non-null  int32
#  16  Dept_Hours       13351 non-null  int32
# ...

# %%
final_df['duration_minutes']=final_df['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Duration  Total_Stops Additional_Info    Price  Date  Month  Year  \
# 0    22:20   2h 50m          0.0         No info   3897.0    24      3  2019
# 1    05:50   7h 25m          2.0         No info   7662.0     1      5  2019
# 2    09:25      19h          2.0         No info  13882.0     9      6  2019
# 3    18:05   5h 25m          1.0         No info   6218.0    12      5  2019
# 4    16:50   4h 45m          1.0         No info  13302.0     1      3  2019
#
# ...

# %%
final_df.drop('Duration',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Total_Stops Additional_Info    Price  Date  Month  Year  \
# 0    22:20          0.0         No info   3897.0    24      3  2019
# 1    05:50          2.0         No info   7662.0     1      5  2019
# 2    09:25          2.0         No info  13882.0     9      6  2019
# 3    18:05          1.0         No info   6218.0    12      5  2019
# 4    16:50          1.0         No info  13302.0     1      3  2019
#
#    Arrival_Minutes  Arrival_Hours  Dept_Minutes  Dept_Hours duration_hours  \
# ...

# %%
final_df['duration_minutes'].mode()
# Out:
# 0    30
# Name: duration_minutes, dtype: object

# %%
final_df.isnull().sum()
# Out:
# Airline                0
# Date_of_Journey        0
# Source                 0
# Destination            0
# Route                  1
# Dep_Time               0
# Total_Stops            1
# Additional_Info        0
# Price               2670
# Date                   0
# Month                  0
# Year                   0
# Arrival_Minutes        0
# Arrival_Hours          0
# Dept_Minutes           0
# Dept_Hours             0
# duration_hours         0
# duration_minutes    1283
# dtype: int64

# %%
#We will replace it with mode
final_df['duration_minutes']=final_df['duration_minutes'].fillna(final_df['duration_minutes'].mode()[0])

# %%
final_df.isnull().sum()
# Out:
# Airline                0
# Date_of_Journey        0
# Source                 0
# Destination            0
# Route                  1
# Dep_Time               0
# Total_Stops            1
# Additional_Info        0
# Price               2670
# Date                   0
# Month                  0
# Year                   0
# Arrival_Minutes        0
# Arrival_Hours          0
# Dept_Minutes           0
# Dept_Hours             0
# duration_hours         0
# duration_minutes       0
# dtype: int64

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13351 entries, 0 to 2670
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Airline           13351 non-null  object
#  1   Date_of_Journey   13351 non-null  object
#  2   Source            13351 non-null  object
#  3   Destination       13351 non-null  object
#  4   Route             13350 non-null  object
#  5   Dep_Time          13351 non-null  object
#  6   Total_Stops       13350 non-null  float64
#  7   Additional_Info   13351 non-null  object
#  8   Price             10681 non-null  float64
#  9   Date              13351 non-null  int32
#  10  Month             13351 non-null  int32
#  11  Year              13351 non-null  int32
#  12  Arrival_Minutes   13351 non-null  int32
#  13  Arrival_Hours     13351 non-null  int32
#  14  Dept_Minutes      13351 non-null  int32
#  15  Dept_Hours        13351 non-null  int32
# ...

# %%
final_df['duration_hours']=final_df['duration_hours'].astype(int)
final_df['duration_minutes']=final_df['duration_minutes'].astype(int)

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Total_Stops Additional_Info    Price  Date  Month  Year  \
# 0    22:20          0.0         No info   3897.0    24      3  2019
# 1    05:50          2.0         No info   7662.0     1      5  2019
# 2    09:25          2.0         No info  13882.0     9      6  2019
# 3    18:05          1.0         No info   6218.0    12      5  2019
# 4    16:50          1.0         No info  13302.0     1      3  2019
#
#    Arrival_Minutes  Arrival_Hours  Dept_Minutes  Dept_Hours  duration_hours  \
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13351 entries, 0 to 2670
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Airline           13351 non-null  object
#  1   Date_of_Journey   13351 non-null  object
#  2   Source            13351 non-null  object
#  3   Destination       13351 non-null  object
#  4   Route             13350 non-null  object
#  5   Dep_Time          13351 non-null  object
#  6   Total_Stops       13350 non-null  float64
#  7   Additional_Info   13351 non-null  object
#  8   Price             10681 non-null  float64
#  9   Date              13351 non-null  int32
#  10  Month             13351 non-null  int32
#  11  Year              13351 non-null  int32
#  12  Arrival_Minutes   13351 non-null  int32
#  13  Arrival_Hours     13351 non-null  int32
#  14  Dept_Minutes      13351 non-null  int32
#  15  Dept_Hours        13351 non-null  int32
# ...

# %%
final_df['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

# %%
final_df['Airline']=labelencoder.fit_transform( final_df['Airline']) 
final_df['Source']=labelencoder.fit_transform( final_df['Source']) 
final_df['Destination']=labelencoder.fit_transform( final_df['Destination']) 
final_df['Additional_Info']=labelencoder.fit_transform( final_df['Additional_Info'])

# %%
final_df.drop('Date_of_Journey',axis=1,inplace=True)
final_df.drop('Route',axis=1,inplace=True)
final_df.drop('Dep_Time',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info    Price  Date  \
# 0        3       0            5          0.0                8   3897.0    24
# 1        1       3            0          2.0                8   7662.0     1
# 2        4       2            1          2.0                8  13882.0     9
# 3        3       3            0          1.0                8   6218.0    12
# 4        3       0            5          1.0                8  13302.0     1
#
#    Month  Year  Arrival_Minutes  Arrival_Hours  Dept_Minutes  Dept_Hours  \
# 0      3  2019                1             10            22          20
# 1      5  2019               13             15             5          50
# 2      6  2019                4             25             9          25
# 3      5  2019               23             30            18           5
# 4      3  2019               21             35            16          50
#
#    duration_hours  duration_minutes
# ...

# %%
final_df.shape
# Out:
# (13351, 15)
